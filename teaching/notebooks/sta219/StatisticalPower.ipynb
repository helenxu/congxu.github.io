# %% [markdown]
# # ============ Example 6.4 ============#

# %%
import numpy as np
from scipy.stats import norm


def Testing(n, p_true, p0, alpha):
    # p_true is the true value
    sample = np.random.binomial(1, p_true, n)
    p_hat = np.mean(sample)
    test_stat = (p_hat - p0) / np.sqrt(p0 * (1 - p0) / n)
    # the alternative hypothesis is one-sided, right-tailed
    z_alpha = norm.ppf(1 - alpha) # ppf is the inverse of CDF
    if test_stat > z_alpha:
        return 1 # reject
    else:
        return 0 # fail to reject

# %% [markdown]
# ### First consider the case when p_true = 0.025, p0 = 0.02

# %%
np.random.seed(12321)
rep = 10000
cnt = 0

n = 1000 # if sample size is only 1000

for i in range(rep):
    cnt = cnt + Testing(n, 0.025, 0.02, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# Out:
# When the sample size is 1000:
# 	 number of times fail to reject: 6967
# 	 power of the test: 0.3033

# %%
np.random.seed(12321)
cnt = 0
n = 5000 # if sample size is 5000

for i in range(rep):
    cnt = cnt + Testing(n, 0.025, 0.02, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# 5000 is still not enough
# Out:
# When the sample size is 5000:
# 	 number of times fail to reject: 2205
# 	 power of the test: 0.7795

# %%
np.random.seed(12321)
cnt = 0
n = 7412 # if sample size is 7412

for i in range(rep):
    cnt = cnt + Testing(n, 0.025, 0.02, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# Out:
# When the sample size is 7412:
# 	 number of times fail to reject: 1005
# 	 power of the test: 0.8995

# %% [markdown]
# ### Then consider the case when p_true = 0.05, p0 = 0.02

# %%
np.random.seed(12321)
rep = 10000
cnt = 0

n = 200 # if sample size is only 200

for i in range(rep):
    cnt = cnt + Testing(n, 0.05, 0.02, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# 200 is not enough
# Out:
# When the sample size is 200:
# 	 number of times fail to reject: 2079
# 	 power of the test: 0.7921

# %%
np.random.seed(12321)
rep = 10000
cnt = 0

n = 289 # if sample size is 289

for i in range(rep):
    cnt = cnt + Testing(n, 0.05, 0.02, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# actually 280 is enough
# Out:
# When the sample size is 289:
# 	 number of times fail to reject: 807
# 	 power of the test: 0.9193

# %% [markdown]
# ### If alpha is larger, how would the power change?

# %%
np.random.seed(12321)
rep = 10000
cnt = 0
alpha = 0.1 # alpha is increased from 0.05 to 0.1

n = 289 # if sample size is only 289

for i in range(rep):
    cnt = cnt + Testing(n, 0.05, 0.02, alpha)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# Out:
# When the sample size is 289:
# 	 number of times fail to reject: 431
# 	 power of the test: 0.9569

# %% [markdown]
# # ============ Example 6.5 ============

# %%
def Testing2(n, mu_true, mu0, alpha):
    sample = np.random.normal(mu_true, 15, n) # standard deviation is 15
    mu_hat = np.mean(sample)
    test_stat = (mu_hat - mu0) / np.sqrt(15 ** 2 / n)
    # the alternative hypothesis is one-sided, right-tailed
    z_alpha = norm.ppf(1 - alpha) # ppf is the inverse of CDF
    if test_stat > z_alpha:
        return 1 # reject
    else:
        return 0 # fail to reject

# %% [markdown]
# ## Consider the case when mu_true = 105, mu0 = 100

# %%
np.random.seed(12321)
rep = 10000
cnt = 0

n = 78 # if sample size is 78

for i in range(rep):
    cnt = cnt + Testing2(n, 105, 100, 0.05)
power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# Out:
# When the sample size is 78:
# 	 number of times fail to reject: 1034
# 	 power of the test: 0.8966

# %%
np.random.seed(12321)
rep = 10000
cnt = 0

n = 60 # if sample size is only 60

for i in range(rep):
    cnt = cnt + Testing2(n, 105, 100, 0.05)
    power = cnt / rep

print("When the sample size is %s:" % n)
print("\t number of times fail to reject: %s" % (rep - cnt))
print("\t power of the test: %.4f" % (cnt / rep))
# Out:
# When the sample size is 60:
# 	 number of times fail to reject: 1802
# 	 power of the test: 0.8198
